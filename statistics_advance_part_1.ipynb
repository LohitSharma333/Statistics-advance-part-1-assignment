# %% [markdown]
# 1. What is a random variable in probability theory?
# A random variable is a numerical outcome of a random process. It assigns a real number to each possible outcome in a sample space.
#
# 2. What are the types of random variables?
# There are two types of random variables:
#
# Discrete Random Variables: Take countable values (e.g., number of heads in a coin toss).
#
# Continuous Random Variables: Take infinite values within a range (e.g., height, weight).
#
# 3. What is the difference between discrete and continuous distributions?
# Discrete Distribution	Continuous Distribution
# Defined for countable outcomes	Defined for uncountable outcomes
# Uses probability mass function (PMF)	Uses probability density function (PDF)
# Example: Binomial, Poisson	Example: Normal, Exponential
# 4. What are probability distribution functions (PDF)?
# A probability distribution function (PDF) describes the likelihood of different outcomes in a probability distribution.
#
# For discrete variables: Probability Mass Function (PMF) gives exact probabilities.
#
# For continuous variables: Probability Density Function (PDF) gives probabilities over intervals.
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# CDF: Gives the probability that a variable takes a value less than or equal to
# 𝑥
# x.
#
# PDF: Gives the probability density at a specific point (for continuous distributions).
#
# For any
# 𝑥
# x,
#
# 𝐶
# 𝐷
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# =
# ∫
# −
# ∞
# 𝑥
# 𝑃
# 𝐷
# 𝐹
# (
# 𝑡
# )
# 𝑑
# 𝑡
# CDF(x)=P(X≤x)=∫
# −∞
# x
# ​
#  PDF(t)dt
# 6. What is a discrete uniform distribution?
# A discrete uniform distribution assigns equal probability to all outcomes within a finite range. Example: Rolling a fair die (
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 𝑛
# P(X=x)=
# n
# 1
# ​
#   for
# 𝑛
# n possible values).
#
# 7. What are the key properties of a Bernoulli distribution?
# Models a single trial with two possible outcomes: Success (1) or Failure (0).
#
# Probability Mass Function (PMF):
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# 𝑥
# (
# 1
# −
# 𝑝
# )
# 1
# −
# 𝑥
# ,
# 𝑥
# ∈
# {
# 0
# ,
# 1
# }
# P(X=x)=p
# x
#  (1−p)
# 1−x
#  ,x∈{0,1}
# Mean:
# 𝑝
# p, Variance:
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p).
#
# 8. What is the binomial distribution, and how is it used in probability?
# Models the number of successes in
# 𝑛
# n independent Bernoulli trials with success probability
# 𝑝
# p.
#
# Probability Mass Function (PMF):
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Used in coin flips, quality control, A/B testing.
#
# 9. What is the Poisson distribution and where is it applied?
# Models the number of events occurring in a fixed interval of time or space when events happen randomly and independently.
#
# PMF:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#
# Used in queue theory, call center arrivals, rare event modeling.
#
# 10. What is a continuous uniform distribution?
# A continuous uniform distribution assigns equal probability density to all values within a range
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b].
#
# PDF:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# ,
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  ,a≤x≤b
# Used in random sampling, simulation models.
#
# 11. What are the characteristics of a normal distribution?
# Bell-shaped and symmetric about the mean.
#
# Mean = Median = Mode.
#
# Fully defined by mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ.
#
# 68%-95%-99.7% Rule applies.
#
# 12. What is the standard normal distribution, and why is it important?
# A normal distribution with mean = 0 and standard deviation = 1.
#
# Used in Z-scores, hypothesis testing, and standardization.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# The CLT states that the sum (or mean) of a large number of independent, identically distributed (i.i.d) random variables follows a normal distribution, regardless of the original distribution.
#
# Essential for hypothesis testing and confidence intervals.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
# Even if data is not normally distributed, the CLT ensures that the sampling distribution of the sample mean is approximately normal for large samples (
# 𝑛
# ≥
# 30
# n≥30).
#
# 15. What is the application of Z statistics in hypothesis testing?
# Used when population standard deviation is known.
#
# Helps determine whether a sample mean is significantly different from the population mean.
#
# 16. How do you calculate a Z-score, and what does it represent?
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Measures how many standard deviations a value is from the mean.
#
# 17. What are point estimates and interval estimates in statistics?
# Point Estimate: A single value estimate of a population parameter (e.g., sample mean).
#
# Interval Estimate: A range of values that likely contains the population parameter (e.g., confidence interval).
#
# 18. What is the significance of confidence intervals in statistical analysis?
# Provides a range within which the population parameter likely falls.
#
# A 95% confidence interval means that, in repeated sampling, 95% of such intervals contain the true parameter.
#
# 19. What is the relationship between a Z-score and a confidence interval?
# Z-scores are used to compute confidence intervals when population standard deviation is known.
#
# A 95% confidence interval uses Z = 1.96.
#
# 20. How are Z-scores used to compare different distributions?
# Standardizes different datasets by transforming them to a standard normal distribution.
#
# Allows comparison across different scales.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# Independence: Observations must be independent.
#
# Identical Distribution: Data must come from the same distribution.
#
# Sufficient Sample Size:
# 𝑛
# ≥
# 30
# n≥30 is usually sufficient.
#
# 22. What is the concept of expected value in a probability distribution?
# The expected value (mean) of a random variable is the long-run average outcome.
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑥
# 𝑃
# (
# 𝑥
# )
# (for discrete)
# or
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# 𝑥
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# (for continuous)
# E(X)=∑xP(x)(for discrete)orE(X)=∫xf(x)dx(for continuous)
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# The expected value is the weighted average of all possible outcomes, weighted by their probabilities.
